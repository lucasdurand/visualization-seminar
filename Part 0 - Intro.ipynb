# %%
# where is the config directory?
# !jupyter --paths
# Out:
# config:
#     C:\Users\DURANL4\.jupyter
#     c:\users\duranl4\.virtualenvs\visualization-seminar-qrgs2xap\etc\jupyter
#     C:\ProgramData\jupyter
# data:
#     C:\Users\DURANL4\AppData\Roaming\jupyter
#     c:\users\duranl4\.virtualenvs\visualization-seminar-qrgs2xap\share\jupyter
#     C:\ProgramData\jupyter
# runtime:
#     C:\Users\DURANL4\AppData\Roaming\jupyter\runtime

# %%
# set the theme for this to use a Serif font. That looks nicer.

from traitlets.config.manager import BaseJSONConfigManager
import os
jupyter = r"c:\users\duranl4\.virtualenvs\visualization-seminar-qrgs2xap\etc\jupyter"
path = os.path.join(jupyter,"nbconfig")
cm = BaseJSONConfigManager(config_dir=path)
cm.update("livereveal", {
              "theme": "serif",
              "transition": "zoom",
              "start_slideshow_at": "selected",
})
# Out:
# {'theme': 'serif', 'transition': 'zoom', 'start_slideshow_at': 'selected'}

# %% [markdown]
# # Who is this?
#
# ![Lucas Durand](https://media.licdn.com/dms/image/C4E03AQH4IqbY1sqyjw/profile-displayphoto-shrink_200_200/0?e=1573084800&v=beta&t=BFC1fzs4Yqw3IPexAVmITutpff1PMoc0eyjqckJEy68)
#
# https://www.linkedin.com/in/lucasdurand/

# %% [markdown]
# # BUT FIRST
#
# Did you set up your Python environment for this course?
#
# http://lucasdurand.xyz/visualization-seminar/README-setup.html

# %% [markdown]
# ## Lucas Durand
#
# - Python Developer and Data Scientist
# - Ex-Theoretical Physicist
# - I work for TD Securities:
#     - I manage a Data Science Team
#     - I'm the tech lead for Data Science Tooling

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.xkcd();
years = {
    'python': [1]*10,
    'jupyter': [1]*10,
    'matplotlib': [1]*7+[0]*3,
    'tableau': [0]*3+[1]*4+[0]*3,
    'seaborn': [0]*7+[1]*2+[0],
    'plotly': [0]*7+[1]*3,
    'dash': [0]*9 + [1],
    'plotly express': [0]*9+[1]*1
}

experience = pd.DataFrame(years)
experience.index.name="years"

# %% [markdown]
# ## My Favourite Tools

# %%
experience.plot(kind='area', title="Data Visualization Tools", figsize=(10,6));

# %%
experience.plot(kind='area', title="Data Visualization Tools", figsize=(8,3), legend=False);

# %% [markdown]
# ### Was this ^ a great plot?
#
# Not really ...
