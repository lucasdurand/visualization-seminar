# %% [markdown]
# # How do I share this?
#
# It isn't immediately clear how this can be done. Do you save the file and email it to someone? Can they access the link?
#
# We are going to focus on two main ways to share:
#
# - HTML
# - NBViewer

# %% [markdown]
# # First
#
# **What should we share?**
#
# I think the work we did on Global Temperature changes warrants sending out into the world.

# %% [markdown]
# ## EXERCISE
#
# - Create a new Notebook in this folder and populate it with the **important** pieces of our *Global Temperatures* analysis
# - Let's copy everything we need into this folder (that means the data files from ../data)
# - Make sure the code runs! You will need to change your data imports to point to this folder
# - Intersperse your code with useful explanations using markdown cells

# %% [markdown]
# ## HTML
#
# As simple as saving the file. It is converted using a library called `nbconvert` and can be turned into many different forms (including PDF). What makes `HTML` great is that it is able to embed both standard images generated by `matplotlib` as well as interactive plots (that we will make later).
#
# ### mini exercise
#
# - Download your new Notebook as HTML and see how it looks in the browser

# %% [markdown]
# ## NBViewer
#
# * `nbconvert` as a service: https://nbviewer.jupyter.org/
# * requires having your code in a repo
